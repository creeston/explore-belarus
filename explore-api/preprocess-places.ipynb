# %%
with open('places.json', 'r', encoding='utf-8') as f:
    import json
    places = json.load(f)
len(places)

description_to_rate_mapping = {
    'взглянуть': 3, 'увидеть интересно': 2, 'увидеть обязательно': 1, 'увидеть по дороге': 4
}

prop_key_name_correction_mapping = {
    'Даты строи-тельства': 'Даты строительства',
    "Дата строи-тельства": 'Даты строительства / обновления',
    'Гос. цен-ность (0..3)': 'Гос. ценность (0..3)',
    "Рейтинг(1..4)": "Рейтинг (1..4)",
}

date_property_names = [
    'Дата',
    'Дата установки',
    'Дата строительства',
    'Даты строительства',
    'Даты / обновления',
    'Даты строительства',
    'Даты строительства / обновления',
    'Дата основания'
]

def get_sight_date(props):
    for date_property_name in date_property_names:
        if date_property_name in props:
            return props[date_property_name]
    return None

def get_sight_prop_value(props, prop_name):
    if prop_name not in props:
        return None
    return props[prop_name]


def convert_props_to_dict(props):
    props = {}
    for prop_key, value in sight['props']:
        if prop_key in prop_key_name_correction_mapping:
            prop_key = prop_key_name_correction_mapping[prop_key]
        props[prop_key] = value
    return props


def get_coords(props):
    coord = get_sight_prop_value(props, 'Координаты')
    if coord:
            return (coord, True)
    else:
        potential_coord = get_sight_prop_value(props, 'Предполагаемые  координаты')
        if potential_coord:
            return (potential_coord, True)
    return None

def get_sight_rate(props):
    rate = get_sight_prop_value(props, 'Рейтинг (1..4)')
    if rate:
        rate = int(description_to_rate_mapping[rate])
    return rate


def get_sight_categories(props):
    tags = []
    tag_list = get_sight_prop_value(props, 'Списки')
    if tag_list:
        tags = split_tags(tag_list)
    return tags


def get_sight_image_url(sight):
    image_url = sight['image']
    if image_url:
        start_index = image_url.rindex('https')
        image_url = image_url[start_index:]
        sight['image'] = image_url
    return image_url


import re

tags_to_remove = ['Топ 100', 'Топ 20']

def split_tags(tag_list):
    for tag in tags_to_remove:
        tag_list = tag_list.replace(tag, '')
    # Regex pattern to match uppercase Cyrillic letters
    pattern = r'(?<=[а-яё\.\)\d])([А-ЯЁ])'

    # Insert a separator character before each uppercase Cyrillic letter except the first one
    modified_string = re.sub(pattern, r'|\1', tag_list)

    pattern = r'(?<=[а-яё\)])([1-9])'

    modified_string = re.sub(pattern, r'|\1', modified_string)

    # Split the modified string using the separator character to get the list of items
    result = modified_string.split('|')

    return result


sight_id = 0
sights_db = []
for i, p in enumerate(places):
    p['coords'] = p['info']['coords']
    p['location'] = p['info']['location']
    if 'name' in p['info']:
        p['name'] = p['info']['name']
    p['sights'] = p['info']['sights']
    p['rating'] = int(p['rating'])
    p['id'] = i
    del p['info']
    for sight in p['sights']:
        sight['id'] = sight_id
        sight_id += 1
        
        sight['image'] = get_sight_image_url(sight)

        props = convert_props_to_dict(sight['props'])
        sight['coord'] = get_coords(props)
        sight['hint'] = get_sight_prop_value(props, 'Ориентир')
        sight['date'] = get_sight_date(props)
        sight['rate'] = get_sight_rate(props)
        sight['state_rate'] = get_sight_prop_value(props, 'Гос. ценность (0..3)')
        sight['status'] = get_sight_prop_value(props, 'Статус')
        sight['address'] = get_sight_prop_value(props, 'Адрес')
        sight['style'] = get_sight_prop_value(props, 'Стиль')
        sight['tags'] = get_sight_categories(props)
        sight['props'] = props

# %%
sights = []
for p in places:
    place_pointer = {
            'id': p['id'],
            'name': p['name'],
            'rating': p['rating'],
            'location': p['location'],
            'coords': p['coords']
        }
    for sight in p['sights']:
        sight_record = dict(sight)
        sight_record['place'] = place_pointer
        sights.append(sight_record)

# %%
with open('places_db.json', 'w', encoding='utf-8') as f:
    json.dump({"places": places, 'sights': sights}, f, indent=4, ensure_ascii=False)

# %%
categories = set()
for place in places:
    for sight in place['sights']:
        for category in sight['tags']:
            categories.add(category)
categories
# Out:
# {'',
#  '1-я мировая война',
#  '1-я мировая война (?)',
#  'Аптеки',
#  'Арочные мосты',
#  'Банки и казначейства',
#  'Башни',
#  'Башни оборонительного типа',
#  'Борисовы камни',
#  'Брамы',
#  'Брамы (?)',
#  'Брамы (избранное)',
#  'Бровары и винокурни',
#  'Бровары и винокурни (?)',
#  'Ветряные мельницы',
#  'Ветряные электрогенераторы',
#  'Водяные мельницы',
#  'Водяные мельницы (?)',
#  'Вокзалы и ж/д станции',
#  'Восстание 1830-31 гг.',
#  'Восстание 1863-64 гг.',
#  'Восстание 1863-64 гг. (?)',
#  'Восстание Костюшко 1794 г.',
#  'Гаштольды',
#  'Гаштольды (?)',
#  'Гмины, староства, воеводства',
#  'Городница',
#  'Гостиницы и заезжие дворы',
#  'Греко-католические церкви действующие',
#  'Дворцы',
#  'Дворцы (?)',
#  'Деревянное зодчество (избранное)',
#  'Деревянные костелы (избранное)',
#  'Деревянные церкви (избранное)',
#  'Дом-крепость',
#  'Дома-музеи',
#  'Дуга Струве',
#  'Еврейское наследие',
#  'Еврейское наследие (?)',
#  'Заброшенные и захороненные деревни',
#  'Замки',
#  'Иешивы',
#  'Иешивы (?)',
#  'Интересная география',
#  'Интересные надмогилья',
#  'Интересные названия',
#  'Иоанн Павел II',
#  'Кагальные колодцы',
#  'Кальвинские сборы',
#  'Кальвинские сборы (?)',
#  'Каменные кресты',
#  'Камни и валуны',
#  'Каретные и гаражи',
#  'Каретные и гаражи (?)',
#  'Карьеры',
#  'Кирхи',
#  'Кладбища еврейские',
#  'Кладбища лютеранские',
#  'Кладбища татарские',
#  'Кладбища татарские (?)',
#  'Коллегиумы иезуитов',
#  'Колокольни (избранное)',
#  'Колонны и обелиски',
#  'Корпус охраны пограничья',
#  'Корчмы и аустерии',
#  'Корчмы и аустерии (?)',
#  'Костелы (избранное)',
#  'Крепости',
#  'Кресты-обереги придорожные',
#  'Лютеранское наследие',
#  'Лютеранское наследие (?)',
#  'Машины-памятники',
#  'Мельницы',
#  'Мельницы (?)',
#  'Мемориальные камни',
#  'Мечети и молельные дома',
#  'Монастыри базилиан',
#  'Монастыри бенедиктинцев',
#  'Монастыри бернардинцев',
#  'Монастыри бонифратов',
#  'Монастыри доминиканцев',
#  'Монастыри иезуитов',
#  'Монастыри кармелитов',
#  'Монастыри картезианцев',
#  'Монастыри мариан',
#  'Монастыри миссионеров',
#  'Монастыри назаретянок',
#  'Монастыри пиаров',
#  'Монастыри правосл. действ.',
#  'Монастыри православные',
#  'Монастыри тринитариев',
#  'Монастыри францисканцев',
#  'Монастыри цистерцианцев',
#  'Немецкие кладбища 1-й мировой',
#  'Немецкие кладбища 1-й мировой (?)',
#  'Немецкие кладбища 2-й мировой',
#  'Оборонительные храмы',
#  'Оборонительные храмы (?)',
#  'Объекты 1500-1599 гг.',
#  'Объекты 1500-1599 гг. (?)',
#  'Объекты 1600-1699 гг.',
#  'Объекты 1600-1699 гг. (?)',
#  'Объекты до 1499 г.',
#  'Объекты до 1499 г. (?)',
#  'Озера и водохранилища',
#  'Орден августинцев',
#  'Орден базилиан',
#  'Орден бенедиктинцев',
#  'Орден бернардинцев',
#  'Орден бернардинцев (?)',
#  'Орден доминиканцев',
#  'Орден иезуитов',
#  'Орден иоаннитов (рыцарей мальтийского ордена)',
#  'Орден каноников латеранских (августинцев)',
#  'Орден каноников регулярных (августинцев)',
#  'Орден кармелитов',
#  'Орден кармелитов (?)',
#  'Орден коммунистов',
#  'Орден мариавиток',
#  'Орден миссионеров',
#  'Орден назаретянок',
#  'Орден пиаров',
#  'Орден рохитов',
#  'Орден трапистов',
#  'Орден францисканцев',
#  'Орден цистерцианцев',
#  'Орден шкаплеров',
#  'Отечественная война 1812 г. (?)',
#  'Паровые мельницы',
#  'Паровые мельницы (?)',
#  'Паромы',
#  'Пещеры',
#  'Плебании',
#  'Плебании (?)',
#  'Подвесные мосты',
#  'Пожарные',
#  'Пожарные (?)',
#  'Польские кладбища войны 1919-21 гг.',
#  'Польские кладбища войны 1919-21 гг. (?)',
#  'Почтовые станции и заставные дома',
#  'Почтовые станции и заставные дома (?)',
#  'Примечательные могилы',
#  'Производство',
#  'Производство (?)',
#  'Промышленность',
#  'Протестантские храмы действующие',
#  'Протестантские храмы действующие (?)',
#  'Радзивиллы',
#  'Ратуши',
#  'Реки и каналы',
#  'Русские кладбища 1-й мировой',
#  'Русские кладбища 1-й мировой (?)',
#  'Русско-французская война 1812 г.',
#  'Сапеги',
#  'Сапеги (?)',
#  'Северная война 1700-21 гг.',
#  'Северная война 1700-21 гг. (?)',
#  'Синагога (?)',
#  'Синагоги',
#  'Синагоги (?)',
#  'Синагоги (избранное)',
#  'Синагоги действующие',
#  'Солнечные часы',
#  'Сталин',
#  'Старообрядческие церкви',
#  'Старообрядческие церкви (?)',
#  'Старые дороги',
#  'Татарское наследие',
#  'Торговые ряды',
#  'Тюрьмы',
#  'Тюрьмы (?)',
#  'Усадьбы и фольварки',
#  'Усадьбы и фольварки (?)',
#  'Утраченные недавно',
#  'Фотозарисовки',
#  'Ходкевичи',
#  'Холодная война',
#  'Хрептовичи',
#  'Церкви (избранное)',
#  'Часовни (избранное)',
#  'Часовни придорожные (избранное)',
#  'Шуховские башни',
#  'Языческое наследие',
#  'Языческое наследие (?)'}

# %%
for place in places:
    for sight in place['sights']:
        date_props = [p for p in sight['props'] if 'дат' in p.lower()]
        if len(date_props) > 1:
            print(sight['name'])
            print(sight['props'])
            print()

# %%
sight_to_rate = []
for place in places:
    rate = place['rating']
    for sight in place['sights']:
        if not sight['rate']:
            sight_rate = rate * 4
        else:
            sight_rate = sight['rate'] * rate
        sight_to_rate.append((sight, sight_rate, place))

# %%
sorted_sights = sorted(sight_to_rate, key=lambda triple: triple[1])
for sight, rate, place in sorted_sights[:10]:
    print(place['name'], rate)
    print(json.dumps(sight, indent=4, ensure_ascii=False))
    print()
# Out:
# Ружаны 1
# {
#     "name": "дворцовый комплекс Сапег",
#     "image": "https://orda.of.by/.ga/r/ruzhany/palace/nf/ruzhany_12.jpg",
#     "coord": [
#         "52.860723, 24.895983 (*)",
#         true
#     ],
#     "hint": null,
#     "building_date": "1598—1605 гг., 1748—86 гг.",
#     "foundation_date": null,
#     "rate": 1,
#     "state_rate": null,
#     "status": null,
#     "address": null,
#     "style": "переход от позднего барокко к классицизму",
#     "tags": [
#         "Топ 20",
#         "Топ 100",
#         "Объекты 1600-1699 гг.",
#         "Дворцы",
#         "Усадьбы и фольварки",
#         "Сапеги"
#     ]
# }
#
# Жиличи 1
# {
#     "name": "усадьба Булгаков \"Добосна\"",
#     "image": null,
#     "coord": null,
#     "hint": null,
#     "building_date": "XVIII—XIX вв.",
#     "foundation_date": null,
#     "rate": 1,
#     "state_rate": null,
#     "status": null,
#     "address": null,
#     "style": null,
#     "tags": [
#         "Усадьбы и фольварки"
#     ]
# }
#
# Жиличи 1
# {
#     "name": "усадьба: дворец",
#     "image": "https://globustut.by/zhilichi_kirov/palace0310_d181.jpg",
#     "coord": [
#         "53.155810, 29.689269 (*)",
#         true
#     ],
#     "hint": null,
#     "building_date": null,
#     "foundation_date": null,
#     "rate": 1,
#     "state_rate": null,
#     "status": null,
#     "address": null,
#     "style": null,
#     "tags": [
#         "Топ 100",
#         "Дворцы"
#     ]
# }
#
# Жировичи 1
# {
#     "name": "монастырь правосл. Успенский",
#     "image": "https://globustut.by/zhirovichi/monast_main2465_d298.jpg",
#     "coord": [
#         "53.014882, 25.345181 (*)",
#         true
#     ],
#     "hint": null,
#     "building_date": null,
#     "foundation_date": "основ. 1470 г.",
#     "rate": 1,
#     "state_rate": "1",
#     "status": null,
#     "address": "ул. Советская, 57",
#     "style": null,
#     "tags": [
#         "Топ 100",
#         "Монастыри базилиан",
#         "Монастыри православные",
#         "Монастыри правосл. действ."
#     ]
# }
#
# Жировичи 1
# {
#     "name": "монастырь:  собор Успенский",
#     "image": "https://globustut.by/zhirovichi/uspen_sobor0475_d177.jpg",
#     "coord": [
#         "53.014827, 25.344526 (*)",
#         true
#     ],
#     "hint": null,
#     "building_date": "1613—50 гг. / до 1667 г. / 1828—39 гг.",
#     "foundation_date": null,
#     "rate": 1,
#     "state_rate": "1",
#     "status": null,
#     "address": null,
#     "style": "барокко и классицизм",
#     "tags": [
#         "Объекты 1600-1699 гг.",
#         "Церкви (избранное)"
#     ]
# }
#
# Сарья 1
# {
#     "name": "церковь Успенская",
#     "image": "https://globustut.by/sarya/kostel1_d26.jpg",
#     "coord": [
#         "55.915122, 27.887308 (*)",
#         true
#     ],
#     "hint": null,
#     "building_date": "1852—57 гг.",
#     "foundation_date": null,
#     "rate": 1,
#     "state_rate": null,
#     "status": null,
#     "address": null,
#     "style": "ретроспективно-готический (по Кулагину), неоготика",
#     "tags": [
#         "Топ 20",
#         "Топ 100",
#         "Церкви (избранное)"
#     ]
# }
#
# Береза 1
# {
#     "name": "монастырь картезианцев (руины)",
#     "image": "https://globustut.by/bereza/monast_main027_d68.jpg",
#     "coord": [
#         "52.53322, 24.95936 (*)",
#         true
#     ],
#     "hint": null,
#     "building_date": "1648—89 гг.",
#     "foundation_date": null,
#     "rate": 1,
#     "state_rate": null,
#     "status": null,
#     "address": null,
#     "style": "зрелое барокко",
#     "tags": [
#         "Топ 100",
#         "Монастыри картезианцев",
#         "Восстание 1830-31 гг."
#     ]
# }
#
# Бобруйск 1
# {
#     "name": "крепость",
#     "image": null,
#     "coord": [
#         "53.139387, 29.244769 (*)",
#         true
#     ],
#     "hint": null,
#     "building_date": "1807—36 гг.",
#     "foundation_date": null,
#     "rate": 1,
#     "state_rate": null,
#     "status": null,
#     "address": null,
#     "style": null,
#     "tags": [
#         "Топ 100",
#         "Крепости",
#         "Русско-французская война 1812 г."
#     ]
# }
#
# Закозель 1
# {
#     "name": "усадьба Ожешко",
#     "image": null,
#     "coord": null,
#     "hint": null,
#     "building_date": "XIX в.",
#     "foundation_date": null,
#     "rate": 1,
#     "state_rate": null,
#     "status": null,
#     "address": null,
#     "style": null,
#     "tags": [
#         "Усадьбы и фольварки"
#     ]
# }
#
# Закозель 1
# {
#     "name": "усадьба:  часовня-усыпальница Ожешко",
#     "image": "https://globustut.by/zakozel/chapel646_a92.jpg",
#     "coord": [
#         "52.129144, 25.002659 (*)",
#         true
#     ],
#     "hint": null,
#     "building_date": "1849 г.",
#     "foundation_date": null,
#     "rate": 1,
#     "state_rate": null,
#     "status": null,
#     "address": null,
#     "style": "ретроспективно-готический, неоготика",
#     "tags": [
#         "Топ 100",
#         "Часовни (избранное)",
#         "Восстание 1863-64 гг."
#     ]
# }

# %%
sight_props = set()
for place in places:
    for sight in place['sights']:
        for prop_key, value in sight['props'].items():
            sight_props.add(prop_key)
sight_props
# Out:
# {'Адрес',
#  'Гос. ценность (0..3)',
#  'Дата',
#  'Дата основания',
#  'Дата строительства',
#  'Дата установки',
#  'Даты / обновления',
#  'Даты строительства',
#  'Даты строительства / обновления',
#  'Координаты',
#  'На старых картах',
#  'Ориентир',
#  'Предполагаемые  координаты',
#  'Рейтинг (1..4)',
#  'Списки',
#  'Статус',
#  'Стиль'}

# %%
def display_possible_values(prop_name):
    values = set()
    for place in places:
        for sight in place['sights']:
            if prop_name not in sight['props']:
                continue
            values.add(sight['props'][prop_name])
    return values

# %%
for sight_prop in sight_props:
    values = list(display_possible_values(sight_prop))
    print(sight_prop, len(values))
    print(values[:5])
    print()
# Out:
# Координаты 3125
# ['54.586959, 29.740172 (*)', '54.366383, 26.661196 (*)', '53.246187, 24.241047 (*)', '54.427397, 25.934637 (*)', '54.084465, 30.768924 (*)']
#
# Дата 217
# ['1975 г.', 'XVI в.', '1920 г.', '1974 г.', 'XVIII—XX вв.']
#
# Даты строительства 10
# ['1597—98 гг.? / XVII в. / XIX в.', '1643—46 гг. / 2-я половина XVIII в.', '1637 г.—2-я половина XVII в. / 1746—50 гг.', '1830-е гг. / 1864—76 гг.', '1750 г. / 1830—35 гг.']
#
# Адрес 401
# ['ул. Энгельса', 'ул. Лопатина, 38', 'ул. Ленинская, 59', 'ул. Ленина', 'ул. Маркса, 29']
#
# Дата основания 57
# ['основ. 1-я половина XVII в.?', 'основ. 1992 г.', 'основ. 1128 г.', 'основ. 1883 г.', 'основ. 1628 г.']
#
# Даты / обновления 8
# ['середина XVIII в. / 1-я половина XIX в.', '1793 г. / 1830 г.', 'начало XIX в. / конец XIX в.', '1912 г. / 1962 г.', '2-я половина XVIII в. / конец XIX—начало XX вв.']
#
# Ориентир 1101
# ['на деревенском кладбище, в центре кладбища', 'позади часовни-усыпальницы', 'на северо-восточной окраине города', 'между Мяделем и дер. Бояры, в лесу', 'на выезде на Слоним']
#
# Даты строительства / обновления 247
# ['конец XVII—начало XVIII вв. / 1830-е гг.', 'XIX в.? / после 1990 г.', 'XIX в. / 1990-е гг.', 'XVI—XVII вв. / после 1863 г.', 'конец XIX—начало XX вв. / середина XX в.?']
#
# Гос. ценность (0..3) 4
# ['3', '2', '0', '1']
#
# Списки 421
# ['Монастыри иезуитовМонастыри бернардинцевМонастыри доминиканцевМонастыри православныеМонастыри правосл. действ.', 'ПроизводствоУтраченные недавно', 'Башни', 'Монастыри мариан', 'Церкви (избранное)Восстание 1863-64 гг.']
#
# На старых картах 1
# ['[1], [2], [3]']
#
# Стиль 135
# ['древнерусское зодчество', 'черты классицизма', 'переход от позднего барокко к классицизму', 'неоклассицизм (?)', 'черты готики и ренессанса']
#
# Предполагаемые  координаты 1101
# ['53.598499, 24.990257 (*)', '53.312781, 25.698672 (*)', '53.009077, 26.675718 (*)', '54.2217, 27.26838 (*)', '54.476658, 27.655455 (*)']
#
# Дата строительства 1079
# ['1740 г.', '1860 г., 1879 г.', '1899 г.?', '1920 г.', '1940 г.']
#
# Дата установки 42
# ['1932 г.', '1896 г.', '1988 г.', '2013 г.', 'XIX в.?']
#
# Статус 1
# ['объект не сохранился']
#
# Рейтинг (1..4) 4
# ['взглянуть', 'увидеть обязательно', 'увидеть по дороге', 'увидеть интересно']
